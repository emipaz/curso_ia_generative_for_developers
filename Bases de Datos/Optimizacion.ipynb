# %% [markdown]
# # <center> FullORM</center>

# %%
from sqlalchemy import create_engine 
from sqlalchemy import Column, Integer, String, ForeignKey
from sqlalchemy.orm import declarative_base, sessionmaker, relationship 

import pickle

# %%
Base = declarative_base()

# %%
class User(Base):
    __tablename__ = 'users'
    
    id     = Column(Integer, primary_key=True)
    name   = Column(String(100))  # Límite de 100 caracteres
    email  = Column(String(120), unique=True)  # Límite de 120 caracteres y es unica
    orders = relationship("Order", back_populates="user")
    # back_populates="user" significa que la clase Order 
    # también tiene una relación de vuelta hacia User.
    def __str__(self):
        return self.name + "con mail :" + self.email

# %%
class Product(Base):
    __tablename__ = 'products'
    
    id          = Column(Integer, primary_key=True)
    name        = Column(String(200))  # Limit to 200 characters
    price       = Column(Integer)
    #relacion 
    order_items = relationship("OrderItem", back_populates="product")
    # significa que la clase OrderItem tiene un campo que apunta de vuelta al producto.

# %%
class Order(Base):
    __tablename__ = 'orders'
    
    id          = Column(Integer, primary_key=True)
                # user_id Es una clave foránea (ForeignKey) que apunta al campo id de la tabla users.
    user_id     = Column(Integer, ForeignKey('users.id'))
    # Relaciones
    # Establece la relación Python entre Order y User.
    # Permite acceder al usuario que hizo el pedido: pedido.user.
    user        = relationship("User", back_populates="orders")
    order_items = relationship("OrderItem", back_populates="order") 
    #indica que en la clase OrderItem también existe un campo order que enlaza de vuelta.

# %%
class OrderItem(Base):
    __tablename__ = 'order_items'
    
    id         = Column(Integer, primary_key=True)
    order_id   = Column(Integer, ForeignKey('orders.id')) 
    product_id = Column(Integer, ForeignKey('products.id'))
    quantity   = Column(Integer)
    # relacones
    order   = relationship("Order", back_populates="order_items")
    product = relationship("Product", back_populates="order_items")

# %%
engine = create_engine('sqlite:///comercio2.db', echo=True)
Base.metadata.create_all(engine)
# Out:
# 2025-05-26 20:48:09,533 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:09,548 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("users")
# 2025-05-26 20:48:09,562 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-05-26 20:48:09,573 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("products")
# 2025-05-26 20:48:09,577 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-05-26 20:48:09,584 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("orders")
# 2025-05-26 20:48:09,589 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-05-26 20:48:09,593 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("order_items")
# 2025-05-26 20:48:09,596 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-05-26 20:48:09,609 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# Prepara una fábrica de sesiones para conectarse a la base.
#
# session = Session() crea una sesión activa que usarás para agregar, consultar o modificar datos.

# %%
Session = sessionmaker(bind=engine)
session = Session()

# %% [markdown]
# ## Crud para la tabla User

# %%
# Create
def add_user(name, email):
    try:
        new_user = User(name=name, email=email)
        session.add(new_user)
        session.commit()
    except Exception as e:
        print(e)
        session.rollback()

# Read
def get_user(user_id=None):
    if user_id is not None:
        return session.query(User).filter(User.id == user_id).first()
    else:
         return session.query(User).all()
# Update
def update_user(user_id, name=None, email=None):
    user = session.query(User).filter(User.id == user_id).first()
    if user:
        if name:
            user.name = name
        if email:
            user.email = email
        session.commit()

# Delete
def delete_user(user_id):
    user = session.query(User).filter(User.id == user_id).first()
    if user:
        session.delete(user)
        session.commit()

# %%
add_user("emiliano"*100, "emi@ht.com")
# Out:
# 2025-05-26 20:49:46,855 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2025-05-26 20:49:46,858 INFO sqlalchemy.engine.Engine [cached since 82.89s ago] ('emilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemili ... (502 characters truncated) ... lianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemilianoemiliano', 'emi@ht.com')
# 2025-05-26 20:49:46,865 INFO sqlalchemy.engine.Engine COMMIT

# %%
usuarios = get_user()

# %%
for usuario in usuarios:
    print(usuario)
# Out:
# ... mail :emi@ht.com

# %%
## PRODUCT TABLE CRUD
# Create
def add_product(name, price):
    new_product = Product(name=name, price=price)
    session.add(new_product)
    session.commit()

# Read
def get_product(product_id):
    return session.query(Product).filter(Product.id == product_id).first()

# Update
def update_product(product_id, name=None, price=None):
    product = session.query(Product).filter(Product.id == product_id).first()
    if product:
        if name:
            product.name = name
        if price:
            product.price = price
        session.commit()

# Delete
def delete_product(product_id):
    product = session.query(Product).filter(Product.id == product_id).first()
    if product:
        session.delete(product)
        session.commit()

# %%
## ORDERS TABLE CRUD
# Create
def add_order(user_id):
    new_order = Order(user_id=user_id)
    session.add(new_order)
    session.commit()

# Read
def get_order(order_id):
    return session.query(Order).filter(Order.id == order_id).first()

# Update
def update_order(order_id, user_id=None):
    order = session.query(Order).filter(Order.id == order_id).first()
    if order:
        if user_id:
            order.user_id = user_id
        session.commit()

# Delete
def delete_order(order_id):
    order = session.query(Order).filter(Order.id == order_id).first()
    if order:
        session.delete(order)
        session.commit()

# %%
## ORDER ITEMS CRUD
# Create
def add_order_item(order_id, product_id, quantity):
    new_order_item = OrderItem(order_id=order_id, product_id=product_id, quantity=quantity)
    session.add(new_order_item)
    session.commit()

# Read
def get_order_item(order_item_id):
    return session.query(OrderItem).filter(OrderItem.id == order_item_id).first()

# Update
def update_order_item(order_item_id, order_id=None, product_id=None, quantity=None):
    order_item = session.query(OrderItem).filter(OrderItem.id == order_item_id).first()
    if order_item:
        if order_id:
            order_item.order_id = order_id
        if product_id:
            order_item.product_id = product_id
        if quantity:
            order_item.quantity = quantity
        session.commit()

# Delete
def delete_order_item(order_item_id):
    order_item = session.query(OrderItem).filter(OrderItem.id == order_item_id).first()
    if order_item:
        session.delete(order_item)
        session.commit()

# %%
def add_sample_data():
    # Adding users
    user_data = [
        ("Alice", "alice@example.com"),
        ("Bob", "bob@example.com"),
        ("Charlie", "charlie@example.com"),
        ("David", "david@example.com"),
        ("Eve", "eve@example.com"),
        ("Frank", "frank@example.com"),
        ("Grace", "grace@example.com"),
        ("Heidi", "heidi@example.com"),
        ("Ivan", "ivan@example.com"),
        ("Judy", "judy@example.com")
    ]
    for name, email in user_data:
        add_user(name, email)

    # Adding products
    product_data = [
        ("Laptop", 1000),
        ("Smartphone", 500),
        ("Tablet", 300),
        ("Monitor", 150),
        ("Keyboard", 50),
        ("Mouse", 25),
        ("Printer", 200),
        ("Router", 75),
        ("Webcam", 60),
        ("Headphones", 80)
    ]
    for name, price in product_data:
        add_product(name, price)

    # Adding orders
    for i in range(1, 11):
        add_order(i)

    # Adding order_items
    order_item_data = [
        (1, 1, 2),
        (1, 2, 1),
        (2, 3, 1),
        (2, 4, 2),
        (3, 5, 3),
        (3, 6, 1),
        (4, 7, 2),
        (4, 8, 1),
        (5, 9, 1),
        (5, 10, 2),
        (6, 1, 1),
        (6, 2, 2),
        (7, 3, 1),
        (7, 4, 1),
        (8, 5, 2),
        (8, 6, 1),
        (9, 7, 3),
        (9, 8, 1),
        (10, 9, 1),
        (10, 10, 1)
    ]
    for order_id, product_id, quantity in order_item_data:
        add_order_item(order_id, product_id, quantity)

    #Pickle this data
    # Combine data into a single dictionary
    combined_data = {
        'user_data': user_data,
        'product_data': product_data,
        'order_item_data': order_item_data
    }

    # Pickling the combined data to a single file
    with open('sample_data.pkl', 'wb') as f:
        pickle.dump(combined_data, f)

# Call the function to add sample data
add_sample_data()
# Out:
# 2025-05-26 20:48:23,962 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:23,969 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2025-05-26 20:48:23,975 INFO sqlalchemy.engine.Engine [generated in 0.00627s] ('Alice', 'alice@example.com')
# 2025-05-26 20:48:23,979 INFO sqlalchemy.engine.Engine ROLLBACK
# (sqlite3.IntegrityError) UNIQUE constraint failed: users.email
# [SQL: INSERT INTO users (name, email) VALUES (?, ?)]
# [parameters: ('Alice', 'alice@example.com')]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# 2025-05-26 20:48:23,996 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:23,999 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2025-05-26 20:48:24,002 INFO sqlalchemy.engine.Engine [cached since 0.03258s ago] ('Bob', 'bob@example.com')
# 2025-05-26 20:48:24,005 INFO sqlalchemy.engine.Engine ROLLBACK
# (sqlite3.IntegrityError) UNIQUE constraint failed: users.email
# [SQL: INSERT INTO users (name, email) VALUES (?, ?)]
# [parameters: ('Bob', 'bob@example.com')]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# 2025-05-26 20:48:24,015 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,018 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2025-05-26 20:48:24,020 INFO sqlalchemy.engine.Engine [cached since 0.05123s ago] ('Charlie', 'charlie@example.com')
# 2025-05-26 20:48:24,023 INFO sqlalchemy.engine.Engine ROLLBACK
# (sqlite3.IntegrityError) UNIQUE constraint failed: users.email
# [SQL: INSERT INTO users (name, email) VALUES (?, ?)]
# [parameters: ('Charlie', 'charlie@example.com')]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# 2025-05-26 20:48:24,033 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,035 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2025-05-26 20:48:24,040 INFO sqlalchemy.engine.Engine [cached since 0.0707s ago] ('David', 'david@example.com')
# 2025-05-26 20:48:24,049 INFO sqlalchemy.engine.Engine ROLLBACK
# (sqlite3.IntegrityError) UNIQUE constraint failed: users.email
# [SQL: INSERT INTO users (name, email) VALUES (?, ?)]
# [parameters: ('David', 'david@example.com')]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# 2025-05-26 20:48:24,079 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,084 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2025-05-26 20:48:24,088 INFO sqlalchemy.engine.Engine [cached since 0.1191s ago] ('Eve', 'eve@example.com')
# 2025-05-26 20:48:24,097 INFO sqlalchemy.engine.Engine ROLLBACK
# (sqlite3.IntegrityError) UNIQUE constraint failed: users.email
# [SQL: INSERT INTO users (name, email) VALUES (?, ?)]
# [parameters: ('Eve', 'eve@example.com')]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# 2025-05-26 20:48:24,105 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,113 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2025-05-26 20:48:24,116 INFO sqlalchemy.engine.Engine [cached since 0.1468s ago] ('Frank', 'frank@example.com')
# 2025-05-26 20:48:24,154 INFO sqlalchemy.engine.Engine ROLLBACK
# (sqlite3.IntegrityError) UNIQUE constraint failed: users.email
# [SQL: INSERT INTO users (name, email) VALUES (?, ?)]
# [parameters: ('Frank', 'frank@example.com')]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# 2025-05-26 20:48:24,164 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,167 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2025-05-26 20:48:24,170 INFO sqlalchemy.engine.Engine [cached since 0.2014s ago] ('Grace', 'grace@example.com')
# 2025-05-26 20:48:24,183 INFO sqlalchemy.engine.Engine ROLLBACK
# (sqlite3.IntegrityError) UNIQUE constraint failed: users.email
# [SQL: INSERT INTO users (name, email) VALUES (?, ?)]
# [parameters: ('Grace', 'grace@example.com')]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# 2025-05-26 20:48:24,202 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,225 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2025-05-26 20:48:24,235 INFO sqlalchemy.engine.Engine [cached since 0.2658s ago] ('Heidi', 'heidi@example.com')
# 2025-05-26 20:48:24,241 INFO sqlalchemy.engine.Engine ROLLBACK
# (sqlite3.IntegrityError) UNIQUE constraint failed: users.email
# [SQL: INSERT INTO users (name, email) VALUES (?, ?)]
# [parameters: ('Heidi', 'heidi@example.com')]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# 2025-05-26 20:48:24,255 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,261 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2025-05-26 20:48:24,274 INFO sqlalchemy.engine.Engine [cached since 0.3053s ago] ('Ivan', 'ivan@example.com')
# 2025-05-26 20:48:24,288 INFO sqlalchemy.engine.Engine ROLLBACK
# (sqlite3.IntegrityError) UNIQUE constraint failed: users.email
# [SQL: INSERT INTO users (name, email) VALUES (?, ?)]
# [parameters: ('Ivan', 'ivan@example.com')]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# 2025-05-26 20:48:24,306 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,312 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2025-05-26 20:48:24,318 INFO sqlalchemy.engine.Engine [cached since 0.3494s ago] ('Judy', 'judy@example.com')
# 2025-05-26 20:48:24,327 INFO sqlalchemy.engine.Engine ROLLBACK
# (sqlite3.IntegrityError) UNIQUE constraint failed: users.email
# [SQL: INSERT INTO users (name, email) VALUES (?, ?)]
# [parameters: ('Judy', 'judy@example.com')]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# 2025-05-26 20:48:24,429 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,439 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2025-05-26 20:48:24,445 INFO sqlalchemy.engine.Engine [generated in 0.00671s] ('Laptop', 1000)
# 2025-05-26 20:48:24,482 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:24,517 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,520 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2025-05-26 20:48:24,528 INFO sqlalchemy.engine.Engine [cached since 0.08381s ago] ('Smartphone', 500)
# 2025-05-26 20:48:24,533 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:24,562 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,564 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2025-05-26 20:48:24,567 INFO sqlalchemy.engine.Engine [cached since 0.129s ago] ('Tablet', 300)
# 2025-05-26 20:48:24,574 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:24,599 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,602 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2025-05-26 20:48:24,605 INFO sqlalchemy.engine.Engine [cached since 0.1666s ago] ('Monitor', 150)
# 2025-05-26 20:48:24,613 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:24,631 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,634 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2025-05-26 20:48:24,637 INFO sqlalchemy.engine.Engine [cached since 0.1989s ago] ('Keyboard', 50)
# 2025-05-26 20:48:24,645 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:24,654 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,664 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2025-05-26 20:48:24,668 INFO sqlalchemy.engine.Engine [cached since 0.2293s ago] ('Mouse', 25)
# 2025-05-26 20:48:24,702 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:24,724 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,728 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2025-05-26 20:48:24,730 INFO sqlalchemy.engine.Engine [cached since 0.2918s ago] ('Printer', 200)
# 2025-05-26 20:48:24,738 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:24,749 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,752 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2025-05-26 20:48:24,755 INFO sqlalchemy.engine.Engine [cached since 0.3162s ago] ('Router', 75)
# 2025-05-26 20:48:24,764 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:24,783 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,786 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2025-05-26 20:48:24,802 INFO sqlalchemy.engine.Engine [cached since 0.364s ago] ('Webcam', 60)
# 2025-05-26 20:48:24,834 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:24,854 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,859 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2025-05-26 20:48:24,864 INFO sqlalchemy.engine.Engine [cached since 0.4253s ago] ('Headphones', 80)
# 2025-05-26 20:48:24,885 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:24,901 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,906 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2025-05-26 20:48:24,910 INFO sqlalchemy.engine.Engine [generated in 0.00419s] (1,)
# 2025-05-26 20:48:24,915 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:24,929 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,937 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2025-05-26 20:48:24,945 INFO sqlalchemy.engine.Engine [cached since 0.03893s ago] (2,)
# 2025-05-26 20:48:24,954 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:24,979 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:24,982 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2025-05-26 20:48:24,985 INFO sqlalchemy.engine.Engine [cached since 0.07959s ago] (3,)
# 2025-05-26 20:48:24,997 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,029 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,034 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2025-05-26 20:48:25,037 INFO sqlalchemy.engine.Engine [cached since 0.1312s ago] (4,)
# 2025-05-26 20:48:25,046 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,057 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,063 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2025-05-26 20:48:25,066 INFO sqlalchemy.engine.Engine [cached since 0.1601s ago] (5,)
# 2025-05-26 20:48:25,083 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,119 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,128 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2025-05-26 20:48:25,130 INFO sqlalchemy.engine.Engine [cached since 0.2243s ago] (6,)
# 2025-05-26 20:48:25,134 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,140 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,146 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2025-05-26 20:48:25,149 INFO sqlalchemy.engine.Engine [cached since 0.2437s ago] (7,)
# 2025-05-26 20:48:25,153 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,167 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,169 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2025-05-26 20:48:25,171 INFO sqlalchemy.engine.Engine [cached since 0.2654s ago] (8,)
# 2025-05-26 20:48:25,178 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,185 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,188 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2025-05-26 20:48:25,192 INFO sqlalchemy.engine.Engine [cached since 0.286s ago] (9,)
# 2025-05-26 20:48:25,199 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,211 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,213 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2025-05-26 20:48:25,222 INFO sqlalchemy.engine.Engine [cached since 0.3159s ago] (10,)
# 2025-05-26 20:48:25,229 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,260 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,269 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,273 INFO sqlalchemy.engine.Engine [generated in 0.00486s] (1, 1, 2)
# 2025-05-26 20:48:25,281 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,369 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,394 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,401 INFO sqlalchemy.engine.Engine [cached since 0.1325s ago] (1, 2, 1)
# 2025-05-26 20:48:25,406 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,415 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,430 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,434 INFO sqlalchemy.engine.Engine [cached since 0.1658s ago] (2, 3, 1)
# 2025-05-26 20:48:25,446 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,456 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,466 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,475 INFO sqlalchemy.engine.Engine [cached since 0.2067s ago] (2, 4, 2)
# 2025-05-26 20:48:25,481 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,491 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,495 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,497 INFO sqlalchemy.engine.Engine [cached since 0.229s ago] (3, 5, 3)
# 2025-05-26 20:48:25,501 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,509 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,512 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,515 INFO sqlalchemy.engine.Engine [cached since 0.2462s ago] (3, 6, 1)
# 2025-05-26 20:48:25,519 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,537 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,542 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,552 INFO sqlalchemy.engine.Engine [cached since 0.2833s ago] (4, 7, 2)
# 2025-05-26 20:48:25,557 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,567 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,569 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,581 INFO sqlalchemy.engine.Engine [cached since 0.3116s ago] (4, 8, 1)
# 2025-05-26 20:48:25,590 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,614 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,616 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,618 INFO sqlalchemy.engine.Engine [cached since 0.3492s ago] (5, 9, 1)
# 2025-05-26 20:48:25,621 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,632 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,635 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,636 INFO sqlalchemy.engine.Engine [cached since 0.368s ago] (5, 10, 2)
# 2025-05-26 20:48:25,640 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,654 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,658 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,661 INFO sqlalchemy.engine.Engine [cached since 0.3927s ago] (6, 1, 1)
# 2025-05-26 20:48:25,666 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,686 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,697 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,699 INFO sqlalchemy.engine.Engine [cached since 0.431s ago] (6, 2, 2)
# 2025-05-26 20:48:25,706 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,713 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,715 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,716 INFO sqlalchemy.engine.Engine [cached since 0.4478s ago] (7, 3, 1)
# 2025-05-26 20:48:25,720 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,767 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,772 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,776 INFO sqlalchemy.engine.Engine [cached since 0.5075s ago] (7, 4, 1)
# 2025-05-26 20:48:25,793 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,803 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,811 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,813 INFO sqlalchemy.engine.Engine [cached since 0.5446s ago] (8, 5, 2)
# 2025-05-26 20:48:25,821 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,835 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,839 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,845 INFO sqlalchemy.engine.Engine [cached since 0.5768s ago] (8, 6, 1)
# 2025-05-26 20:48:25,861 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,870 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,872 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,878 INFO sqlalchemy.engine.Engine [cached since 0.6092s ago] (9, 7, 3)
# 2025-05-26 20:48:25,884 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,892 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,895 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,897 INFO sqlalchemy.engine.Engine [cached since 0.6283s ago] (9, 8, 1)
# 2025-05-26 20:48:25,901 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:25,961 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:25,963 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:25,969 INFO sqlalchemy.engine.Engine [cached since 0.7006s ago] (10, 9, 1)
# 2025-05-26 20:48:25,973 INFO sqlalchemy.engine.Engine COMMIT
# 2025-05-26 20:48:26,000 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:26,003 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2025-05-26 20:48:26,005 INFO sqlalchemy.engine.Engine [cached since 0.7367s ago] (10, 10, 1)
# 2025-05-26 20:48:26,011 INFO sqlalchemy.engine.Engine COMMIT

# %%
def print_all_users():
    users = session.query(User).all()
    for user in users:
        print(f"User ID: {user.id}, Name: {user.name}, Email: {user.email}")

# Call the function to print all users
print_all_users()
# Out:
# 2025-05-26 20:48:26,081 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:26,094 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.name AS users_name, users.email AS users_email
# FROM users
# 2025-05-26 20:48:26,099 INFO sqlalchemy.engine.Engine [generated in 0.00526s] ()
# User ID: 1, Name: Alice, Email: alice@example.com
# User ID: 2, Name: Bob, Email: bob@example.com
# User ID: 3, Name: Charlie, Email: charlie@example.com
# User ID: 4, Name: David, Email: david@example.com
# User ID: 5, Name: Eve, Email: eve@example.com
# User ID: 6, Name: Frank, Email: frank@example.com
# User ID: 7, Name: Grace, Email: grace@example.com
# User ID: 8, Name: Heidi, Email: heidi@example.com
# User ID: 9, Name: Ivan, Email: ivan@example.com
# User ID: 10, Name: Judy, Email: judy@example.com

# %%
def print_all_orders():
    orders = session.query(Order).all()
    for order in orders:
        print(f"Order ID: {order.id}")
        print(f"User: {order.user.name} (ID: {order.user_id})")
        print("Order Items:")
        for item in order.order_items:
            product = item.product
            print(f"  - {product.name}: {item.quantity} x ${product.price} = ${item.quantity * product.price}")
        total = sum(item.quantity * item.product.price for item in order.order_items)
        print(f"Total: ${total}")
        print("--------------------")

# Call the function to print all orders
print_all_orders()
# Out:
# 2025-05-26 20:48:26,164 INFO sqlalchemy.engine.Engine SELECT orders.id AS orders_id, orders.user_id AS orders_user_id
# FROM orders
# 2025-05-26 20:48:26,173 INFO sqlalchemy.engine.Engine [generated in 0.00933s] ()
# Order ID: 1
# 2025-05-26 20:48:26,183 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.name AS users_name, users.email AS users_email
# FROM users
# WHERE users.id = ?
# 2025-05-26 20:48:26,185 INFO sqlalchemy.engine.Engine [generated in 0.00244s] (1,)
# User: Alice (ID: 1)
# Order Items:
# 2025-05-26 20:48:26,197 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,204 INFO sqlalchemy.engine.Engine [generated in 0.00701s] (1,)
# 2025-05-26 20:48:26,213 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.name AS products_name, products.price AS products_price
# FROM products
# WHERE products.id = ?
# 2025-05-26 20:48:26,216 INFO sqlalchemy.engine.Engine [generated in 0.00370s] (1,)
#   - Laptop: 2 x $1000 = $2000
# 2025-05-26 20:48:26,220 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.name AS products_name, products.price AS products_price
# FROM products
# WHERE products.id = ?
# 2025-05-26 20:48:26,229 INFO sqlalchemy.engine.Engine [cached since 0.01642s ago] (2,)
#   - Smartphone: 1 x $500 = $500
#   - Laptop: 2 x $1000 = $2000
#   - Smartphone: 1 x $500 = $500
# Total: $5000
# --------------------
# Order ID: 2
# 2025-05-26 20:48:26,234 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.name AS users_name, users.email AS users_email
# FROM users
# WHERE users.id = ?
# 2025-05-26 20:48:26,236 INFO sqlalchemy.engine.Engine [cached since 0.05277s ago] (2,)
# User: Bob (ID: 2)
# Order Items:
# 2025-05-26 20:48:26,244 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,253 INFO sqlalchemy.engine.Engine [cached since 0.05622s ago] (2,)
# 2025-05-26 20:48:26,263 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.name AS products_name, products.price AS products_price
# FROM products
# WHERE products.id = ?
# 2025-05-26 20:48:26,264 INFO sqlalchemy.engine.Engine [cached since 0.05185s ago] (3,)
#   - Tablet: 1 x $300 = $300
# 2025-05-26 20:48:26,269 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.name AS products_name, products.price AS products_price
# FROM products
# WHERE products.id = ?
# 2025-05-26 20:48:26,274 INFO sqlalchemy.engine.Engine [cached since 0.06105s ago] (4,)
#   - Monitor: 2 x $150 = $300
#   - Tablet: 1 x $300 = $300
#   - Monitor: 2 x $150 = $300
# Total: $1200
# --------------------
# Order ID: 3
# 2025-05-26 20:48:26,279 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.name AS users_name, users.email AS users_email
# FROM users
# WHERE users.id = ?
# 2025-05-26 20:48:26,283 INFO sqlalchemy.engine.Engine [cached since 0.1003s ago] (3,)
# User: Charlie (ID: 3)
# Order Items:
# 2025-05-26 20:48:26,288 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,289 INFO sqlalchemy.engine.Engine [cached since 0.09267s ago] (3,)
# 2025-05-26 20:48:26,299 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.name AS products_name, products.price AS products_price
# FROM products
# WHERE products.id = ?
# 2025-05-26 20:48:26,303 INFO sqlalchemy.engine.Engine [cached since 0.09076s ago] (5,)
#   - Keyboard: 3 x $50 = $150
# 2025-05-26 20:48:26,309 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.name AS products_name, products.price AS products_price
# FROM products
# WHERE products.id = ?
# 2025-05-26 20:48:26,312 INFO sqlalchemy.engine.Engine [cached since 0.09906s ago] (6,)
#   - Mouse: 1 x $25 = $25
#   - Keyboard: 3 x $50 = $150
#   - Mouse: 1 x $25 = $25
# Total: $350
# --------------------
# Order ID: 4
# 2025-05-26 20:48:26,316 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.name AS users_name, users.email AS users_email
# FROM users
# WHERE users.id = ?
# 2025-05-26 20:48:26,320 INFO sqlalchemy.engine.Engine [cached since 0.1369s ago] (4,)
# User: David (ID: 4)
# Order Items:
# 2025-05-26 20:48:26,330 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,339 INFO sqlalchemy.engine.Engine [cached since 0.1423s ago] (4,)
# 2025-05-26 20:48:26,344 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.name AS products_name, products.price AS products_price
# FROM products
# WHERE products.id = ?
# 2025-05-26 20:48:26,346 INFO sqlalchemy.engine.Engine [cached since 0.1337s ago] (7,)
#   - Printer: 2 x $200 = $400
# 2025-05-26 20:48:26,350 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.name AS products_name, products.price AS products_price
# FROM products
# WHERE products.id = ?
# 2025-05-26 20:48:26,352 INFO sqlalchemy.engine.Engine [cached since 0.1394s ago] (8,)
#   - Router: 1 x $75 = $75
#   - Printer: 2 x $200 = $400
#   - Router: 1 x $75 = $75
# Total: $950
# --------------------
# Order ID: 5
# 2025-05-26 20:48:26,356 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.name AS users_name, users.email AS users_email
# FROM users
# WHERE users.id = ?
# 2025-05-26 20:48:26,361 INFO sqlalchemy.engine.Engine [cached since 0.1776s ago] (5,)
# User: Eve (ID: 5)
# Order Items:
# 2025-05-26 20:48:26,368 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,370 INFO sqlalchemy.engine.Engine [cached since 0.1739s ago] (5,)
# 2025-05-26 20:48:26,382 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.name AS products_name, products.price AS products_price
# FROM products
# WHERE products.id = ?
# 2025-05-26 20:48:26,385 INFO sqlalchemy.engine.Engine [cached since 0.1723s ago] (9,)
#   - Webcam: 1 x $60 = $60
# 2025-05-26 20:48:26,390 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.name AS products_name, products.price AS products_price
# FROM products
# WHERE products.id = ?
# 2025-05-26 20:48:26,396 INFO sqlalchemy.engine.Engine [cached since 0.1835s ago] (10,)
#   - Headphones: 2 x $80 = $160
#   - Webcam: 1 x $60 = $60
#   - Headphones: 2 x $80 = $160
# Total: $440
# --------------------
# Order ID: 6
# 2025-05-26 20:48:26,401 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.name AS users_name, users.email AS users_email
# FROM users
# WHERE users.id = ?
# 2025-05-26 20:48:26,405 INFO sqlalchemy.engine.Engine [cached since 0.2222s ago] (6,)
# User: Frank (ID: 6)
# Order Items:
# 2025-05-26 20:48:26,412 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,415 INFO sqlalchemy.engine.Engine [cached since 0.2189s ago] (6,)
#   - Laptop: 1 x $1000 = $1000
#   - Smartphone: 2 x $500 = $1000
#   - Laptop: 1 x $1000 = $1000
#   - Smartphone: 2 x $500 = $1000
# Total: $4000
# --------------------
# Order ID: 7
# 2025-05-26 20:48:26,419 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.name AS users_name, users.email AS users_email
# FROM users
# WHERE users.id = ?
# 2025-05-26 20:48:26,421 INFO sqlalchemy.engine.Engine [cached since 0.238s ago] (7,)
# User: Grace (ID: 7)
# Order Items:
# 2025-05-26 20:48:26,429 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,430 INFO sqlalchemy.engine.Engine [cached since 0.2335s ago] (7,)
#   - Tablet: 1 x $300 = $300
#   - Monitor: 1 x $150 = $150
#   - Tablet: 1 x $300 = $300
#   - Monitor: 1 x $150 = $150
# Total: $900
# --------------------
# Order ID: 8
# 2025-05-26 20:48:26,487 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.name AS users_name, users.email AS users_email
# FROM users
# WHERE users.id = ?
# 2025-05-26 20:48:26,492 INFO sqlalchemy.engine.Engine [cached since 0.3089s ago] (8,)
# User: Heidi (ID: 8)
# Order Items:
# 2025-05-26 20:48:26,502 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,506 INFO sqlalchemy.engine.Engine [cached since 0.3094s ago] (8,)
#   - Keyboard: 2 x $50 = $100
#   - Mouse: 1 x $25 = $25
#   - Keyboard: 2 x $50 = $100
#   - Mouse: 1 x $25 = $25
# Total: $250
# --------------------
# Order ID: 9
# 2025-05-26 20:48:26,512 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.name AS users_name, users.email AS users_email
# FROM users
# WHERE users.id = ?
# 2025-05-26 20:48:26,513 INFO sqlalchemy.engine.Engine [cached since 0.3299s ago] (9,)
# User: Ivan (ID: 9)
# Order Items:
# 2025-05-26 20:48:26,519 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,520 INFO sqlalchemy.engine.Engine [cached since 0.3233s ago] (9,)
#   - Printer: 3 x $200 = $600
#   - Router: 1 x $75 = $75
#   - Printer: 3 x $200 = $600
#   - Router: 1 x $75 = $75
# Total: $1350
# --------------------
# Order ID: 10
# 2025-05-26 20:48:26,525 INFO sqlalchemy.engine.Engine SELECT users.id AS users_id, users.name AS users_name, users.email AS users_email
# FROM users
# WHERE users.id = ?
# 2025-05-26 20:48:26,527 INFO sqlalchemy.engine.Engine [cached since 0.3438s ago] (10,)
# User: Judy (ID: 10)
# Order Items:
# 2025-05-26 20:48:26,531 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,533 INFO sqlalchemy.engine.Engine [cached since 0.3367s ago] (10,)
#   - Webcam: 1 x $60 = $60
#   - Headphones: 1 x $80 = $80
#   - Webcam: 1 x $60 = $60
#   - Headphones: 1 x $80 = $80
# Total: $280
# --------------------
# Order ID: 11
# User: Alice (ID: 1)
# Order Items:
# 2025-05-26 20:48:26,548 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,550 INFO sqlalchemy.engine.Engine [cached since 0.3535s ago] (11,)
# Total: $0
# --------------------
# Order ID: 12
# User: Bob (ID: 2)
# Order Items:
# 2025-05-26 20:48:26,554 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,557 INFO sqlalchemy.engine.Engine [cached since 0.3608s ago] (12,)
# Total: $0
# --------------------
# Order ID: 13
# User: Charlie (ID: 3)
# Order Items:
# 2025-05-26 20:48:26,564 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,567 INFO sqlalchemy.engine.Engine [cached since 0.3703s ago] (13,)
# Total: $0
# --------------------
# Order ID: 14
# User: David (ID: 4)
# Order Items:
# 2025-05-26 20:48:26,572 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,577 INFO sqlalchemy.engine.Engine [cached since 0.3806s ago] (14,)
# Total: $0
# --------------------
# Order ID: 15
# User: Eve (ID: 5)
# Order Items:
# 2025-05-26 20:48:26,614 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,617 INFO sqlalchemy.engine.Engine [cached since 0.4203s ago] (15,)
# Total: $0
# --------------------
# Order ID: 16
# User: Frank (ID: 6)
# Order Items:
# 2025-05-26 20:48:26,622 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,624 INFO sqlalchemy.engine.Engine [cached since 0.4274s ago] (16,)
# Total: $0
# --------------------
# Order ID: 17
# User: Grace (ID: 7)
# Order Items:
# 2025-05-26 20:48:26,630 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,631 INFO sqlalchemy.engine.Engine [cached since 0.4349s ago] (17,)
# Total: $0
# --------------------
# Order ID: 18
# User: Heidi (ID: 8)
# Order Items:
# 2025-05-26 20:48:26,636 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,639 INFO sqlalchemy.engine.Engine [cached since 0.4422s ago] (18,)
# Total: $0
# --------------------
# Order ID: 19
# User: Ivan (ID: 9)
# Order Items:
# 2025-05-26 20:48:26,646 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,653 INFO sqlalchemy.engine.Engine [cached since 0.4562s ago] (19,)
# Total: $0
# --------------------
# Order ID: 20
# User: Judy (ID: 10)
# Order Items:
# 2025-05-26 20:48:26,662 INFO sqlalchemy.engine.Engine SELECT order_items.id AS order_items_id, order_items.order_id AS order_items_order_id, order_items.product_id AS order_items_product_id, order_items.quantity AS order_items_quantity
# FROM order_items
# WHERE ? = order_items.order_id
# 2025-05-26 20:48:26,665 INFO sqlalchemy.engine.Engine [cached since 0.4684s ago] (20,)
# Total: $0
# --------------------

# %%
def print_all_products():
    products = session.query(Product).all()
    print("All Products:")
    print("-------------")
    for product in products:
        print(f"ID: {product.id}")
        print(f"Name: {product.name}")
        print(f"Price: ${product.price}")
        print("-------------")

# Call the function to print all products
print_all_products()
# Out:
# 2025-05-26 20:48:26,694 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.name AS products_name, products.price AS products_price
# FROM products
# 2025-05-26 20:48:26,699 INFO sqlalchemy.engine.Engine [generated in 0.00467s] ()
# All Products:
# -------------
# ID: 1
# Name: Laptop
# Price: $1000
# -------------
# ID: 2
# Name: Smartphone
# Price: $500
# -------------
# ID: 3
# Name: Tablet
# Price: $300
# -------------
# ID: 4
# Name: Monitor
# Price: $150
# -------------
# ID: 5
# Name: Keyboard
# Price: $50
# -------------
# ID: 6
# Name: Mouse
# Price: $25
# -------------
# ID: 7
# Name: Printer
# Price: $200
# -------------
# ID: 8
# Name: Router
# Price: $75
# -------------
# ID: 9
# Name: Webcam
# Price: $60
# -------------
# ID: 10
# Name: Headphones
# Price: $80
# -------------
# ID: 11
# Name: Laptop
# Price: $1000
# -------------
# ID: 12
# Name: Smartphone
# Price: $500
# -------------
# ID: 13
# Name: Tablet
# Price: $300
# -------------
# ID: 14
# Name: Monitor
# Price: $150
# -------------
# ID: 15
# Name: Keyboard
# Price: $50
# -------------
# ID: 16
# Name: Mouse
# Price: $25
# -------------
# ID: 17
# Name: Printer
# Price: $200
# -------------
# ID: 18
# Name: Router
# Price: $75
# -------------
# ID: 19
# Name: Webcam
# Price: $60
# -------------
# ID: 20
# Name: Headphones
# Price: $80
# -------------

# %% [markdown]
# ## Consultas complejas

# %%
from sqlalchemy.orm import joinedload

# Función para recuperar todos los pedidos de un usuario en particular junto con los artículos en cada pedido
def get_orders_by_user(user_id):
    """
    Recupera todos los pedidos realizados por un usuario específico,
    incluyendo los ítems de cada pedido y los productos asociados a esos ítems.

    Parámetros:
    -----------
    user_id : int
        ID del usuario cuyos pedidos se desean consultar.

    Retorna:
    --------
    list[Order] o None
        Lista de objetos Order si el usuario existe, o None si no se encontró.
        Cada pedido incluye sus order_items y cada ítem su product correspondiente.
    """
    user = (session.query(User)
            # Carga anticipada de la relación User.orders
            .options(joinedload(User.orders)
                      # Carga anticipada de Order.order_items
                     .joinedload(Order.order_items)
                     # Carga anticipada de OrderItem.product
                     .joinedload(OrderItem.product))
             # Filtro por ID de usuario
            .filter(User.id == user_id).first())
    if user:
        # Devuelve los pedidos si se encontró el usuario
        return user.orders
    else:
        return None

# Example usage
user_id = 5  # eemplace con el ID del usuario para el cual desea recuperar pedidos
orders = get_orders_by_user(user_id)
if orders:
    for order in orders:
        print(f"Order ID: {order.id}")
        for item in order.order_items:
            print(f"\033[1m    Product: {item.product.name}, Quantity: {item.quantity}\033[0m")
else:
    print("No se encontraron pedidos para este usuario..")
# Out:
# 2025-05-26 20:48:27,987 INFO sqlalchemy.engine.Engine SELECT anon_1.users_id AS anon_1_users_id, anon_1.users_name AS anon_1_users_name, anon_1.users_email AS anon_1_users_email, products_1.id AS products_1_id, products_1.name AS products_1_name, products_1.price AS products_1_price, order_items_1.id AS order_items_1_id, order_items_1.order_id AS order_items_1_order_id, order_items_1.product_id AS order_items_1_product_id, order_items_1.quantity AS order_items_1_quantity, orders_1.id AS orders_1_id, orders_1.user_id AS orders_1_user_id
# FROM (SELECT users.id AS users_id, users.name AS users_name, users.email AS users_email
# FROM users
# WHERE users.id = ?
#  LIMIT ? OFFSET ?) AS anon_1 LEFT OUTER JOIN orders AS orders_1 ON anon_1.users_id = orders_1.user_id LEFT OUTER JOIN order_items AS order_items_1 ON orders_1.id = order_items_1.order_id LEFT OUTER JOIN products AS products_1 ON products_1.id = order_items_1.product_id
# 2025-05-26 20:48:28,005 INFO sqlalchemy.engine.Engine [generated in 0.02046s] (5, 1, 0)
# Order ID: 5
#     Product: Webcam, Quantity: 1
#     Product: Webcam, Quantity: 1
#     Product: Headphones, Quantity: 2
#     Product: Headphones, Quantity: 2
# Order ID: 15

# %%
from sqlalchemy import func

def get_total_quantity_sold():
    """
    Consulta los productos más vendidos y la cantidad total vendida de cada uno.

    Retorna:
    --------
    list[tuple[int, str, int]]
        Lista de tuplas con: (id del producto, nombre del producto, cantidad total vendida),
        ordenados de mayor a menor.
    """
    query = (session.query(Product.id, 
                           Product.name, 
                           # Suma total de unidades vendidas por producto
                           func.sum(OrderItem.quantity).label('total_vendido')) # Suma total de unidades vendidas por producto
             # Une con los ítems de pedido por ID de producto
             .join(OrderItem, Product.id == OrderItem.product_id)
             # Agrupa por producto
             .group_by(Product.id, Product.name)
             # Ordena de mayor a menor
             .order_by(func.sum(OrderItem.quantity).desc()))
    
    results = query.all() # Ejecuta la consulta y devuelve todos los resultados
    
    return [
        {
            'product_id': result.id,
            'product_nombre': result.name,
            'total_vendido': result.total_vendido
        } for result in results
    ]

# Function to print the results
def print_total_quantity_sold():
    results = get_total_quantity_sold()
    print("Total Quantity Sold for Each Product:")
    print("-------------------------------------")
    for item in results:
        print(f"Product ID: {item['product_id']}")
        print(f"Nombre Producto: {item['product_nombre']}")
        print(f"Total Vendido: {item['total_vendido']}")
        print("-------------------------------------")

# Call the function to print the results
print_total_quantity_sold()
# Out:
# 2025-05-26 20:48:28,918 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.name AS products_name, sum(order_items.quantity) AS total_vendido
# FROM products JOIN order_items ON products.id = order_items.product_id GROUP BY products.id, products.name ORDER BY sum(order_items.quantity) DESC
# 2025-05-26 20:48:28,930 INFO sqlalchemy.engine.Engine [generated in 0.01151s] ()
# Total Quantity Sold for Each Product:
# -------------------------------------
# Product ID: 5
# Nombre Producto: Keyboard
# Total Vendido: 10
# -------------------------------------
# Product ID: 7
# Nombre Producto: Printer
# Total Vendido: 10
# -------------------------------------
# Product ID: 1
# Nombre Producto: Laptop
# Total Vendido: 6
# -------------------------------------
# Product ID: 2
# Nombre Producto: Smartphone
# Total Vendido: 6
# -------------------------------------
# Product ID: 4
# Nombre Producto: Monitor
# Total Vendido: 6
# -------------------------------------
# Product ID: 10
# Nombre Producto: Headphones
# Total Vendido: 6
# -------------------------------------
# Product ID: 3
# Nombre Producto: Tablet
# Total Vendido: 4
# -------------------------------------
# Product ID: 6
# Nombre Producto: Mouse
# Total Vendido: 4
# -------------------------------------
# Product ID: 8
# Nombre Producto: Router
# Total Vendido: 4
# -------------------------------------
# Product ID: 9
# Nombre Producto: Webcam
# Total Vendido: 4
# -------------------------------------

# %% [markdown]
# # Almacenamiento en Cache

# %% [markdown]
# ## Opción 1: Caché en memoria (simple, por código)

# %% [markdown]
# ```python
# from sqlalchemy.orm import sessionmaker
# from sqlalchemy import create_engine
# from functools import lru_cache
#
# engine = create_engine("sqlite:///mi_base.db")
# Session = sessionmaker(bind=engine)
# session = Session()
#
# @lru_cache(maxsize=128)
# def get_usuario_por_id(usuario_id):
#     return session.query(Usuario).filter_by(id=usuario_id).first()
# ```

# %% [markdown]
# Esto mantiene una copia en memoria (por proceso) de hasta 128 resultados de la función.

# %% [markdown]
# ## Opción 2: Usar un sistema de caché como Redis

# %% [markdown]
# Puedes guardar en Redis los resultados de ciertas consultas costosas:

# %% [markdown]
# ```python
# import redis
# import pickle
#
# r = redis.Redis(host='localhost', port=6379, db=0)
#
# def get_usuario_por_id(usuario_id):
#     cache_key = f"usuario:{usuario_id}"
#     cached = r.get(cache_key)
#     if cached:
#         return pickle.loads(cached)
#
#     usuario = session.query(Usuario).filter_by(id=usuario_id).first()
#     if usuario:
#         r.setex(cache_key, 300, pickle.dumps(usuario))  # 5 minutos de cache
#     return usuario
#
# ```

# %% [markdown]
# Redis es un servicio que corre en tu máquina o en un servidor, como si fuera una base de datos en memoria.

# %% [markdown]
# - 🔹 En Ubuntu/Debian:
# ```bash
# sudo apt update
# sudo apt install redis-server
# ```

# %% [markdown]
# - 🔹 En macOS (con Homebrew):
#
# ```bash
# brew install redis
# brew services start redis
# ```

# %% [markdown]
# - 🔹 En Windows:
# Redis no tiene soporte oficial, pero podés:
#
# Usar WSL (Linux en Windows) y seguir el paso de Ubuntu.
#
# O instalarlo con Docker:
#
# ```bash
# docker run -d -p 6379:6379 redis
# ```

# %% [markdown]
# Una vez instalado, podés verificar que funciona con:
#
# ```bash
# redis-cli ping
# ```
#
# Debe responder: PONG

# %% [markdown]
# - ✅ 2. Instalar la librería cliente de Redis en Python
#
# ```bash
# pip install redis
# ```
#
# - 🧪 Prueba simple de conexión
#
# ```python
# import redis
#
# r = redis.Redis(host='localhost', port=6379, db=0)
# r.set("clave", "valor")
# print(r.get("clave"))  # b'valor'
# ```

# %% [markdown]
# ## Uso de dogpile.cache

# %% [markdown]
# Dogpile.cache es una excelente opción para usar caché en Python de forma más estructurada y con soporte para múltiples backends (memoria, archivo, Redis, Memcached, etc.). Funciona muy bien junto a SQLAlchemy, y de hecho es la base del sistema de caché opcional de SQLAlchemy.

# %% [markdown]
# - ✅ ¿Qué es Dogpile.cache?
# Es una biblioteca que gestiona cachés con expiración, y permite que solo una llamada recalcule un valor cuando el caché expira ("dogpile locking"). Es ideal para evitar que muchas consultas golpeen la base de datos innecesariamente.
#
# - 🔧 Instalación
#
# ```bash
# pip install dogpile.cache
# ```
#
# - 🚀 Ejemplo básico con SQLAlchemy
#
# ```python
# from sqlalchemy import create_engine
# from sqlalchemy.orm import sessionmaker
# from dogpile.cache import make_region
# import json
#
# # Configura SQLAlchemy
# engine = create_engine("sqlite:///mi_base.db")
# Session = sessionmaker(bind=engine)
# session = Session()
#
# # Configura el caché (en memoria)
# region = make_region().configure(
#     'dogpile.cache.memory',
#     expiration_time=60  # 1 minuto de expiración
# )
#
# # Suponiendo que tienes una clase Usuario
# def load_usuario(usuario_id):
#     print("→ Consultando base de datos...")
#     usuario = session.query(Usuario).filter_by(id=usuario_id).first()
#     return usuario
#
# @region.cache_on_arguments()
# def get_usuario_cacheado(usuario_id):
#     return load_usuario(usuario_id)
# ```

# %% [markdown]
# - 🧪 Uso
#
# ```python
# # Primera vez: consulta la base
# usuario = get_usuario_cacheado(1)
#
# # Segunda vez (dentro de 60 segundos): viene del caché
# usuario = get_usuario_cacheado(1)
# ```

# %% [markdown]
# Verás que solo se imprime "→ Consultando base de datos..." una vez.
#
# - 📦 Backends disponibles
#
# Puedes cambiar dogpile.cache.memory por otros:
#
# - 'dogpile.cache.redis'
# - 'dogpile.cache.memcached'
# - 'dogpile.cache.dbm' (caché en archivo)
# - 'dogpile.cache.memory_pickle'
#
# Por ejemplo, para usar Redis:
#
# ```python
# region = make_region().configure(
#     'dogpile.cache.redis',
#     arguments = {
#         'host': 'localhost',
#         'port': 6379,
#         'db': 0,
#         'redis_expiration_time': 60,
#     }
# )
# ```

# %% [markdown]
# ## Practica de cache

# %%
import time
from dogpile.cache import make_region
from sqlalchemy.orm import Session

# %%
# Configure the cache region
region = make_region().configure(
    'dogpile.cache.memory',
    expiration_time=3600
)

# %%
@region.cache_on_arguments()
def get_all_products_cached():
    with Session(engine) as session:
        query = session.query(Product)
        return [
            {
                'id': product.id,
                'name': product.name,
                'price': product.price
            } for product in query.all()
        ]

# %%
def get_all_products_uncached():
    with Session(engine) as session:
        query = session.query(Product)
        return [
            {
                'id': product.id,
                'name': product.name,
                'price': product.price
            } for product in query.all()
        ]

# %%
def compare_execution_times(num_iterations=5):
    print(f"Comparación de los tiempos de ejecución a lo largo de {num_iterations} iteraciones:")
    
    # Warm up the cache
    get_all_products_cached()
    
    # Test cached function
    cache_start_time = time.time()
    for _ in range(num_iterations):
        get_all_products_cached()
    cache_end_time = time.time()
    cache_total_time = cache_end_time - cache_start_time
    
    # Test uncached function
    uncache_start_time = time.time()
    for _ in range(num_iterations):
        get_all_products_uncached()
    uncache_end_time = time.time()
    uncache_total_time = uncache_end_time - uncache_start_time
    
    print(f"Tiempo total de la función en caché: {cache_total_time:.6f} segundos")
    print(f"Tiempo promedio de la función en caché: {cache_total_time/num_iterations:.6f} segundos")
    print(f"Tiempo total de función no almacenada en caché: {uncache_total_time:.6f} segundos")
    print(f"Tiempo promedio de función no almacenada en caché: {uncache_total_time/num_iterations:.6f} segundos")
    print(f"Mejora de la velocidad: {uncache_total_time/cache_total_time:.2f}x más rápido con almacenamiento en caché")

# Run the comparison
compare_execution_times()
# Out:
# Comparación de los tiempos de ejecución a lo largo de 5 iteraciones:
# 2025-05-26 20:48:41,978 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:41,980 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.name AS products_name, products.price AS products_price
# FROM products
# 2025-05-26 20:48:41,983 INFO sqlalchemy.engine.Engine [cached since 15.29s ago] ()
# 2025-05-26 20:48:41,986 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-05-26 20:48:41,990 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:41,993 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.name AS products_name, products.price AS products_price
# FROM products
# 2025-05-26 20:48:41,995 INFO sqlalchemy.engine.Engine [cached since 15.3s ago] ()
# 2025-05-26 20:48:41,998 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-05-26 20:48:42,001 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:42,004 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.name AS products_name, products.price AS products_price
# FROM products
# 2025-05-26 20:48:42,006 INFO sqlalchemy.engine.Engine [cached since 15.31s ago] ()
# 2025-05-26 20:48:42,010 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-05-26 20:48:42,013 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:42,015 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.name AS products_name, products.price AS products_price
# FROM products
# 2025-05-26 20:48:42,018 INFO sqlalchemy.engine.Engine [cached since 15.32s ago] ()
# 2025-05-26 20:48:42,022 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-05-26 20:48:42,025 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:42,030 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.name AS products_name, products.price AS products_price
# FROM products
# 2025-05-26 20:48:42,032 INFO sqlalchemy.engine.Engine [cached since 15.34s ago] ()
# 2025-05-26 20:48:42,036 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-05-26 20:48:42,039 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-05-26 20:48:42,042 INFO sqlalchemy.engine.Engine SELECT products.id AS products_id, products.name AS products_name, products.price AS products_price
# FROM products
# 2025-05-26 20:48:42,044 INFO sqlalchemy.engine.Engine [cached since 15.35s ago] ()
# 2025-05-26 20:48:42,047 INFO sqlalchemy.engine.Engine ROLLBACK
# Tiempo total de la función en caché: 0.000402 segundos
# Tiempo promedio de la función en caché: 0.000080 segundos
# Tiempo total de función no almacenada en caché: 0.060273 segundos
# Tiempo promedio de función no almacenada en caché: 0.012055 segundos
# Mejora de la velocidad: 149.77x más rápido con almacenamiento en caché
